# %%
import pandas as pd

Melbourne = pd.read_csv("../data/Melbourne.csv") 
Sydney = pd.read_csv("../data/Sydney.csv")
Brisbane = pd.read_csv("../data/Brisbane.csv")
Tasmania = pd.read_csv("../data/Tasmania.csv")
WesternAustralia = pd.read_csv("../data/WesternAustralia.csv")

# %%
major_cities = [Melbourne, Sydney, Brisbane, Tasmania, WesternAustralia]

for city in major_cities:
    print(city.isnull().all())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21156\2729337940.py in ?()
#       1 major_cities = [Melbourne, Sydney, Brisbane, Tasmania, WesternAustralia]
#       2
#       3 for city in major_cities:
# ----> 4     print(city.isall())
#
# c:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isall'
